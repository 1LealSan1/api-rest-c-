-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [bdPrueba]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 2/2/2024 5:04:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Empleados]

-- %%
/****** Object:  Table [dbo].[Empleados]    Script Date: 2/2/2024 5:04:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Empleados](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[NombreEmpleado] [nvarchar](max) NOT NULL,
	[FechaIngreso] [date] NOT NULL,
	[RFC] [nvarchar](max) NOT NULL,
	[StatusEmpleado] [int] NOT NULL,
	[IdRol] [int] NOT NULL,
	[IdSucursal] [int] NOT NULL,
 CONSTRAINT [PK_Empleados] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 2/2/2024 5:04:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[NombreRol] [nvarchar](max) NOT NULL,
	[StatusRol] [int] NOT NULL,
 CONSTRAINT [PK_Roles] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sucursales]

-- %%
/****** Object:  Table [dbo].[Sucursales]    Script Date: 2/2/2024 5:04:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sucursales](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[NombreSucursal] [nvarchar](max) NOT NULL,
	[StatusSucursal] [int] NOT NULL,
 CONSTRAINT [PK_Sucursales] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20240202203834_initial', N'8.0.0')
GO

-- %% [markdown]
-- # [dbo].[Empleados]

-- %%
SET IDENTITY_INSERT [dbo].[Empleados] ON 
INSERT [dbo].[Empleados] ([Id], [NombreEmpleado], [FechaIngreso], [RFC], [StatusEmpleado], [IdRol], [IdSucursal]) VALUES (1, N'leonel solis', CAST(N'2024-02-02' AS Date), N'123qweasdwe2e', 1, 1, 1)
INSERT [dbo].[Empleados] ([Id], [NombreEmpleado], [FechaIngreso], [RFC], [StatusEmpleado], [IdRol], [IdSucursal]) VALUES (2, N'alex', CAST(N'2024-02-04' AS Date), N'123456qweasde', 1, 2, 2)
INSERT [dbo].[Empleados] ([Id], [NombreEmpleado], [FechaIngreso], [RFC], [StatusEmpleado], [IdRol], [IdSucursal]) VALUES (3, N'solis', CAST(N'2024-02-04' AS Date), N'124456qweasgd', 1, 2, 2)
INSERT [dbo].[Empleados] ([Id], [NombreEmpleado], [FechaIngreso], [RFC], [StatusEmpleado], [IdRol], [IdSucursal]) VALUES (4, N'alejandro sanchez', CAST(N'2023-01-01' AS Date), N'224455qwsfegd', 1, 2, 1)
SET IDENTITY_INSERT [dbo].[Empleados] OFF
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
SET IDENTITY_INSERT [dbo].[Roles] ON 
INSERT [dbo].[Roles] ([Id], [NombreRol], [StatusRol]) VALUES (1, N'Cajero', 1)
INSERT [dbo].[Roles] ([Id], [NombreRol], [StatusRol]) VALUES (2, N'Guardia', 1)
INSERT [dbo].[Roles] ([Id], [NombreRol], [StatusRol]) VALUES (3, N'Gerente de Sistema', 1)
SET IDENTITY_INSERT [dbo].[Roles] OFF
GO

-- %% [markdown]
-- # [dbo].[Sucursales]

-- %%
SET IDENTITY_INSERT [dbo].[Sucursales] ON 
INSERT [dbo].[Sucursales] ([Id], [NombreSucursal], [StatusSucursal]) VALUES (1, N'Los Mochis', 1)
INSERT [dbo].[Sucursales] ([Id], [NombreSucursal], [StatusSucursal]) VALUES (2, N'Los Mochis 2', 1)
INSERT [dbo].[Sucursales] ([Id], [NombreSucursal], [StatusSucursal]) VALUES (3, N'Los Mochis 3', 0)
SET IDENTITY_INSERT [dbo].[Sucursales] OFF
GO

-- %% [markdown]
-- # [FK_Empleados_Roles]

-- %%
ALTER TABLE [dbo].[Empleados]  WITH CHECK ADD  CONSTRAINT [FK_Empleados_Roles] FOREIGN KEY([IdRol])
REFERENCES [dbo].[Roles] ([Id])
GO
ALTER TABLE [dbo].[Empleados] CHECK CONSTRAINT [FK_Empleados_Roles]
GO

-- %% [markdown]
-- # [FK_Empleados_Sucursales]

-- %%
ALTER TABLE [dbo].[Empleados]  WITH CHECK ADD  CONSTRAINT [FK_Empleados_Sucursales] FOREIGN KEY([IdSucursal])
REFERENCES [dbo].[Sucursales] ([Id])
GO
ALTER TABLE [dbo].[Empleados] CHECK CONSTRAINT [FK_Empleados_Sucursales]
GO
